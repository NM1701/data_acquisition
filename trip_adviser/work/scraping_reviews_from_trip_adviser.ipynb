# %% [markdown]
# ## Trip Adviser口コミのスクレイピング
# - 今回は観光地のURLを予め指定して実行。
# - URLの末尾がアクセスタイミングでランダムに変化することが分かったため、それに対応する処理をtry-exceptで追加している。
# - 上記処理を講じても取れない場合も取得できない場合もあるため、その場合は別ページのデータ取得に移る。

# %%
# import
import requests
from requests.exceptions import Timeout
from bs4 import BeautifulSoup
import pandas as pd
import re
import os
from datetime import date
from time import sleep

# %%
def scrape_from_trip_adviser(url_first_half: str = None,
                             url_second_half: str = None,
                             conj: str = "-or",
                             start: int = 0,
                             end: int = 100,
                             every: int = 3,
                             output_dir: str = None,
                            ) -> pd.DataFrame:
    """Trip_Adviserから口コミをスクレイピングする関数"""

    # スクレイピングした口コミをdf_listに格納していく
    df_list = [] 
    # 指定ページ分スクレイピング行う。
    pages = range(start, end, every)

    for page in pages:
        #　1ページ目と2ページ目以降で若干URLが異なるので条件分岐
        if page == 0:
            urlName = url_first_half + url_second_half
            print("------------------------------------------------------")
            print(f"page_now: {page+1}")
            try:
                url = requests.get(urlName, timeout=(7.5, 10.0))
            except Timeout:
                print(f"timeout occurred when url is {urlName}.")
                print(f"We will keep trying to request alternative url.")
                try:
                    urlName = url_first_half + url_second_half[:-10] + "Ka.html"
                    url = requests.get(urlName, timeout=(7.5, 10.0))
                except Timeout:
                    print(f"timeout occurred when url is {urlName}.")
                    print(f"We will keep trying to request alternative url.")
                    try:
                        urlName = url_first_half + url_second_half[:-10] + "Kan.html"
                        url = requests.get(urlName, timeout=(7.5, 10.0))
                    except Timeout:
                        print(f"timeout occurred when url is {urlName}.")
                        print(f"We will move on to the next loop.")
                        continue
        
        else:
            urlName = url_first_half + conj + str(page*10) + url_second_half
            print("------------------------------------------------------")
            print(f"page_now: {page+1}")
            try:
                url = requests.get(urlName, timeout=(7.5, 10.0))
            except Timeout:
                print(f"timeout occurred when url is {urlName}.")
                print(f"We will keep trying to request alternative url.")
                try:
                    urlName = url_first_half + conj + str(page*10) + url_second_half[:-10] + "Ka.html"
                    url = requests.get(urlName, timeout=(7.5, 10.0))
                except Timeout:
                    print(f"timeout occurred when url is {urlName}.")
                    print(f"We will keep trying to request alternative url.")
                    try:
                        urlName = url_first_half + conj + str(page*10) + url_second_half[:-10] + "Kan.html"
                        url = requests.get(urlName, timeout=(7.5, 10.0))
                    except Timeout:
                        print(f"timeout occurred when url is {urlName}.")
                        print(f"We will move on to the next loop.")
                        continue

        print(f"{urlName} found!")
        soup = BeautifulSoup(url.content, "html.parser")

        # HTMLの中から口コミに相当するタグとClassを指定
        review = soup.find_all('span', class_ = 'yCeTE')

        # 抜き出した口コミを順番に格納
        for i in range(len(review)):
            _df = pd.DataFrame({'Number':i+1,
                                'review':[review[i].text]})

            df_list.append(_df)

        # 間隔を空ける
        sleep(1.1)
    
    df_review = pd.concat(df_list).reset_index(drop=True)
    print(f"df_review.shape: {df_review.shape}")
    
    # 出力
    today=date.today()
    os.makedirs(output_dir, exist_ok=True)
    df_review.to_csv(output_dir+str(today)+"scraping_from_trip_adviser.csv", index = False, encoding="utf-8")
    return df_review

# %%
# 今回は"東京駅"の口コミを取得
# 任意のワードで検索する関数は別に用意

url_first_half = "https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews"
url_second_half = "-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html"
start = 0
end = 500
every = 10
output_dir = "../output/"

df_review = scrape_from_trip_adviser(url_first_half=url_first_half,
                                     url_second_half=url_second_half,
                                     start=start,
                                     end=end,
                                     every=every,
                                     output_dir=output_dir,)
df_review
# Out:
# ------------------------------------------------------
# page_now: 1
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Ka.html.
# We will keep trying to request alternative url.
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kan.html found!
# ------------------------------------------------------
# page_now: 11
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or100-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 21
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or200-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 31
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or300-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 41
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or400-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 51
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or500-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 61
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or600-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 71
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or700-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 81
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or800-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 91
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or900-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 101
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or1000-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 111
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or1100-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 121
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or1200-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or1200-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Ka.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or1200-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kan.html.
# We will move on to the next loop.
# ------------------------------------------------------
# page_now: 131
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or1300-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or1300-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Ka.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or1300-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kan.html.
# We will move on to the next loop.
# ------------------------------------------------------
# page_now: 141
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or1400-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or1400-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Ka.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or1400-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kan.html.
# We will move on to the next loop.
# ------------------------------------------------------
# page_now: 151
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or1500-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html.
# We will keep trying to request alternative url.
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or1500-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Ka.html found!
# ------------------------------------------------------
# page_now: 161
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or1600-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 171
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or1700-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 181
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or1800-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 191
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or1900-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 201
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or2000-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 211
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or2100-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 221
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or2200-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 231
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or2300-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 241
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or2400-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 251
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or2500-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 261
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or2600-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 271
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or2700-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or2700-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Ka.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or2700-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kan.html.
# We will move on to the next loop.
# ------------------------------------------------------
# page_now: 281
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or2800-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or2800-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Ka.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or2800-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kan.html.
# We will move on to the next loop.
# ------------------------------------------------------
# page_now: 291
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or2900-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or2900-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Ka.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or2900-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kan.html.
# We will move on to the next loop.
# ------------------------------------------------------
# page_now: 301
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or3000-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or3000-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Ka.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or3000-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kan.html.
# We will move on to the next loop.
# ------------------------------------------------------
# page_now: 311
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or3100-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or3100-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Ka.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or3100-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kan.html.
# We will move on to the next loop.
# ------------------------------------------------------
# page_now: 321
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or3200-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 331
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or3300-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 341
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or3400-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 351
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or3500-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 361
# https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or3600-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html found!
# ------------------------------------------------------
# page_now: 371
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or3700-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or3700-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Ka.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or3700-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kan.html.
# We will move on to the next loop.
# ------------------------------------------------------
# page_now: 381
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or3800-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or3800-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Ka.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or3800-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kan.html.
# We will move on to the next loop.
# ------------------------------------------------------
# page_now: 391
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or3900-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or3900-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Ka.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or3900-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kan.html.
# We will move on to the next loop.
# ------------------------------------------------------
# page_now: 401
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or4000-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or4000-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Ka.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or4000-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kan.html.
# We will move on to the next loop.
# ------------------------------------------------------
# page_now: 411
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or4100-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kanto.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or4100-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Ka.html.
# We will keep trying to request alternative url.
# timeout occurred when url is https://www.tripadvisor.jp/Attraction_Review-g14129528-d550327-Reviews-or4100-Tokyo_Central_Railway_Station-Marunouchi_Chiyoda_Tokyo_Tokyo_Prefecture_Kan.html.
# We will move on to the next loop.
# ------------------------------------------------------
# page_now: 421
